# %% [markdown]
# # **Paulo Henrique RA:152411 Data 09/03/26**

# %% [markdown]
# Variaveis são usadas para armazenar valores Uma string e uma serie de letras em cercadas por aspas ou aspas duplas

# %%
first_name = 'albert'
last_name = 'einstein'
full_name = first_name + ' ' + last_name
print(full_name)
# Out:
# albert einstein

# %% [markdown]
# Uma lista armazena uma serie de itens em uma ordem particular voce pode acessar os itens usando o indice ou com um loop

# %%
finishers = ['sam','bob','ada','bea']
copy_of_finishers = finishers[:]
print(copy_of_finishers)
# Out:
# ['sam', 'bob', 'ada', 'bea']

# %% [markdown]
# Tuplas são similares a listas mas os itens em uma tupla não podem ser modificados

# %%
dimensions =(1920,1080)

# %% [markdown]
# declaracoes se(if) são usadas para testar uma condição em particular e responder apropriadamente

# %%
equals x == 42
not equal x != 42
greater than x > 42
or equal to >= 42
less tahn x < 42
or equal to x <= 42

'trek' in bikes
'surely' not in bikes

game_active = True
can_edit = False

if age >= 18:
  print("You can vote!")

  if age <4:
    ticket_price = 0
  elif age < 18:
    ticket_price = 10
  else:
    ticket_price = 15
# Out:
# Digite sua idade : 500
# You can vote!

# %% [markdown]
# Dicionarios armazenam conexões entre peçãs de informações cada item em um dicionario e um par chave-valor

# %%
alien = {'color': 'green'}
